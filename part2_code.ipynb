# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1fdb56df-6e26-4b60-aaf0-6287b7f980b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fdb56df-6e26-4b60-aaf0-6287b7f980b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving training_set_data.csv to training_set_data.csv

# %%
import pandas as pd
import io
train = pd.read_csv(io.BytesIO(uploaded['training_set_data.csv']))
train.head()
# Out:
#    person_id  age       citizen_status  ... race_other  uninsured  household_id
# 0          1   45        citizen_birth  ...          0          0             1
# 1          2   47        citizen_birth  ...          0          0             1
# 2          4   26        citizen_birth  ...          0          0             2
# 3          5   42  citizen_naturalized  ...          0          0             3
# 4          6   79  citizen_naturalized  ...          0          0             3
#
# [5 rows x 25 columns]

# %%
train.uninsured.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 59592    0
# 59593    0
# 59594    1
# 59595    1
# 59596    0
# Name: uninsured, Length: 59597, dtype: int64>

# %%
# Subplots of stance (hist/ bar vs wins), age, height, reach, weight, bmi
fig, ax = plt.subplots(nrows = 2,
                       ncols = 2,
                       figsize = (14.5, 12))


# Add data to ax0
scatter = ax[0, 0].scatter(x = train['age'],
                      y = train['total_income'],
                      c = train['uninsured'])
# Customize ax0
ax[0, 0].set(title = 'Age v. Income',
        xlabel = 'Age',
        ylabel = 'Income');
# Add a legend to ax0
ax[0, 0].legend(*scatter.legend_elements(), title = 'Uninsured')
# Add a meanline
ax[0, 0].axhline(y = train['total_income'].mean(),
            linestyle = '--');
fig.delaxes(ax = ax[0, 1])
fig.delaxes(ax = ax[1, 0])
fig.delaxes(ax = ax[1, 1])
